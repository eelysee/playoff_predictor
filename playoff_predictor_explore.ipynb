# %%
import pandas as pd
import os

# %%
nbastats = pd.read_csv('nbastats_2022.csv')
nbapo = pd.read_csv('datanba_po_2022.csv')
nbadata = pd.read_csv('datanba_2022.csv')
nbastats_po = pd.read_csv('nbastats_po_2022.csv')
pbpstats = pd.read_csv('pbpstats_2022.csv')
shotdetail = pd.read_csv('shotdetail_2022.csv')
shotdetail_po = pd.read_csv('shotdetail_po_2022.csv')

# %%
nbastats.head()
# Out:
#     GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD WCTIMESTRING  \
# 0  22200001         2            12                   0       1      7:36 PM
# 1  22200001         4            10                   0       1      7:36 PM
# 2  22200001         7             2                  86       1      7:36 PM
# 3  22200001         9             4                   0       1      7:36 PM
# 4  22200001        10             5                  40       1      7:36 PM
#
#   PCTIMESTRING                              HOMEDESCRIPTION  \
# 0        12:00                                          NaN
# 1        12:00  Jump Ball Horford vs. Embiid: Tip to Harris
# 2        11:38                          Brown BLOCK (1 BLK)
# 3        11:35                                          NaN
# 4        11:35                                          NaN
#
#                   NEUTRALDESCRIPTION  \
# 0  Start of 1st Period (7:36 PM EST)
# 1                                NaN
# ...

# %%
nbastats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574410 entries, 0 to 574409
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   GAME_ID                    574410 non-null  int64
#  1   EVENTNUM                   574410 non-null  int64
#  2   EVENTMSGTYPE               574410 non-null  int64
#  3   EVENTMSGACTIONTYPE         574410 non-null  int64
#  4   PERIOD                     574410 non-null  int64
#  5   WCTIMESTRING               574410 non-null  object
#  6   PCTIMESTRING               574410 non-null  object
#  7   HOMEDESCRIPTION            297481 non-null  object
#  8   NEUTRALDESCRIPTION         12299 non-null   object
#  9   VISITORDESCRIPTION         294016 non-null  object
#  10  SCORE                      159376 non-null  object
#  11  SCOREMARGIN                159376 non-null  object
#  12  PERSON1TYPE                574408 non-null  float64
# ...

# %%
nbastats.isna().sum()
# Out:
# GAME_ID                           0
# EVENTNUM                          0
# EVENTMSGTYPE                      0
# EVENTMSGACTIONTYPE                0
# PERIOD                            0
# WCTIMESTRING                      0
# PCTIMESTRING                      0
# HOMEDESCRIPTION              276929
# NEUTRALDESCRIPTION           562111
# VISITORDESCRIPTION           280394
# SCORE                        415034
# SCOREMARGIN                  415034
# PERSON1TYPE                       2
# PLAYER1_ID                        0
# PLAYER1_NAME                  47066
# PLAYER1_TEAM_ID               47759
# PLAYER1_TEAM_CITY             47759
# PLAYER1_TEAM_NICKNAME         47759
# PLAYER1_TEAM_ABBREVIATION     47759
# PERSON2TYPE                       0
# PLAYER2_ID                        0
# PLAYER2_NAME                 385582
# PLAYER2_TEAM_ID              385582
# PLAYER2_TEAM_CITY            385582
# PLAYER2_TEAM_NICKNAME        385582
# PLAYER2_TEAM_ABBREVIATION    385582
# ...

# %%
nbapo.head()
# Out:
#    evt                   wallclk     cl  \
# 0    2  2023-04-16T21:51:03.100Z  12:00
# 1    4  2023-04-16T21:51:06.600Z  11:56
# 2    7  2023-04-16T21:51:25.900Z  11:36
# 3    8  2023-04-16T21:51:29.900Z  11:32
# 4    9  2023-04-16T21:51:34.700Z  11:30
#
#                                                   de  locX  locY  opt1  opt2  \
# 0                                       Start Period     0   -80     0     0
# 1  Jump Ball Adebayo vs Lopez (Butler gains posse...     0   -80     0     0
# 2             [MIA] Adebayo Pullup Jump shot: Missed    11   140     2     0
# 3          [MIL] Antetokounmpo Rebound (Off:0 Def:1)    11   140     0     0
# 4                            Stoppage: Out-of-Bounds     0   -80     0     0
#
#    opt3  opt4  ...         tid      pid  hs  vs      epid       oftid    ord  \
# 0     0     0  ...           0        0   0   0       NaN           0  20000
# 1     0     0  ...  1610612748  1628389   0   0  202710.0  1610612748  60000
# ...

# %%
nbadata.head()
# Out:
#    evt                   wallclk     cl  \
# 0    2  2022-10-18T23:35:25.400Z  12:00
# 1    4  2022-10-18T23:35:27.800Z  11:57
# 2    7      2022-10-18T23:35:46Z  11:38
# 3    9      2022-10-18T23:35:49Z  11:35
# 4   10  2022-10-18T23:35:53.100Z  11:35
#
#                                                   de  locX  locY  opt1  opt2  \
# 0                                       Start Period     0   -80     0     0
# 1  Jump Ball Embiid vs Horford (Harris gains poss...     0   -80     0     0
# 2  [PHI] Embiid Turnaround Fadeaway shot: Missed ...  -118    50     2     0
# 3                 [PHI] Tucker Rebound (Off:1 Def:0)  -118    50     1     0
# 4  [PHI] Tucker Turnover : Out of Bounds Lost Bal...    45    10     0     0
#
#    opt3  opt4  ...         tid     pid  hs  vs      epid       oftid     ord  \
# 0     0     0  ...           0       0   0   0       NaN           0   20000
# 1     0     0  ...  1610612755  203954   0   0  202699.0  1610612755   60000
# ...

# %%
nbastats_po.head()
# Out:
#     GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD WCTIMESTRING  \
# 0  42200101         2            12                   0       1      5:51 PM
# 1  42200101         4            10                   0       1      5:51 PM
# 2  42200101         7             2                  79       1      5:52 PM
# 3  42200101         8             4                   0       1      5:52 PM
# 4  42200101        10             1                  75       1      5:52 PM
#
#   PCTIMESTRING                                    HOMEDESCRIPTION  \
# 0        12:00                                                NaN
# 1        12:00         Jump Ball Lopez vs. Adebayo: Tip to Butler
# 2        11:36                                                NaN
# 3        11:32             G. Antetokounmpo REBOUND (Off:0 Def:1)
# 4        11:23  G. Antetokounmpo 2' Driving Finger Roll Layup ...
#
#                   NEUTRALDESCRIPTION                 VISITORDESCRIPTION  ...  \
# ...

# %%
pbpstats.head()
# Out:
#   ENDTIME                                             EVENTS  FG2A  FG2M  \
# 0   00:04  MISS Horford 25' 3PT Jump Shot\nHarden REBOUND...     0     0
# 1   00:04  MISS Horford 25' 3PT Jump Shot\nHarden REBOUND...     0     0
# 2   00:32  Brown Lost Ball Turnover (P4.T11): Harris STEA...     0     0
# 3   00:58  Smart Bad Pass Turnover (P1.T10): Maxey STEAL ...     0     0
# 4   01:26   Brown 27' 3PT Jump Shot (35 PTS) (Tatum 4 AST)\n     0     0
#
#    FG3A  FG3M    GAMEDATE    GAMEID  NONSHOOTINGFOULSTHATRESULTEDINFTS  \
# 0     1     0  2022-10-18  22200001                                  0
# 1     1     0  2022-10-18  22200001                                  0
# 2     0     0  2022-10-18  22200001                                  0
# 3     0     0  2022-10-18  22200001                                  0
# 4     1     1  2022-10-18  22200001                                  0
#
#    OFFENSIVEREBOUNDS OPPONENT  PERIOD  SHOOTINGFOULSDRAWN  \
# ...

# %%
shotdetail.head()
# Out:
#            GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID      PLAYER_NAME  \
# 0  Shot Chart Detail  22200005              7    1627749  Dejounte Murray
# 1  Shot Chart Detail  22200005             10    1629027       Trae Young
# 2  Shot Chart Detail  22200005             15    1627749  Dejounte Murray
# 3  Shot Chart Detail  22200005             18    1629631  De'Andre Hunter
# 4  Shot Chart Detail  22200005             21    1627749  Dejounte Murray
#
#       TEAM_ID      TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612737  Atlanta Hawks       1                 11                 44
# 1  1610612737  Atlanta Hawks       1                 11                 14
# 2  1610612737  Atlanta Hawks       1                 10                 49
# 3  1610612737  Atlanta Hawks       1                 10                 22
# 4  1610612737  Atlanta Hawks       1                  9                 57
#
# ...

# %%
shotdetail_po.head()
# Out:
#            GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID      PLAYER_NAME  \
# 0  Shot Chart Detail  42200111             10    1627749  Dejounte Murray
# 1  Shot Chart Detail  42200111             15    1629027       Trae Young
# 2  Shot Chart Detail  42200111             20    1628381     John Collins
# 3  Shot Chart Detail  42200111             24    1627749  Dejounte Murray
# 4  Shot Chart Detail  42200111             27    1627749  Dejounte Murray
#
#       TEAM_ID      TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612737  Atlanta Hawks       1                 11                 31
# 1  1610612737  Atlanta Hawks       1                 11                  0
# 2  1610612737  Atlanta Hawks       1                 10                 34
# 3  1610612737  Atlanta Hawks       1                  9                 58
# 4  1610612737  Atlanta Hawks       1                  9                 45
#
# ...

# %%
# not fininshed
df = [nbastats, nbapo, nbadata, nbastats_po, pbpstats, shotdetail, shotdetail_po]
name = []

# %%
# not finished
for i in df:
    display(i.info())
    display(i.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574410 entries, 0 to 574409
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   GAME_ID                    574410 non-null  int64
#  1   EVENTNUM                   574410 non-null  int64
#  2   EVENTMSGTYPE               574410 non-null  int64
#  3   EVENTMSGACTIONTYPE         574410 non-null  int64
#  4   PERIOD                     574410 non-null  int64
#  5   WCTIMESTRING               574410 non-null  object
#  6   PCTIMESTRING               574410 non-null  object
#  7   HOMEDESCRIPTION            297481 non-null  object
#  8   NEUTRALDESCRIPTION         12299 non-null   object
#  9   VISITORDESCRIPTION         294016 non-null  object
#  10  SCORE                      159376 non-null  object
#  11  SCOREMARGIN                159376 non-null  object
#  12  PERSON1TYPE                574408 non-null  float64
# ...

# %%
for i in df:
    display(i.shape)
# Out:
# (574410, 34)
# (39177, 23)
# (588564, 23)
# (38216, 34)
# (486514, 19)
# (217218, 24)
# (14651, 24)

# %%
features = 0
observations = 0
for i in df:
    o,f = i.shape
    features += f
    observations += o

# %%
features
# Out:
# 181

# %%
observations
# Out:
# 1958750
